# %% [markdown]
# # Hamoye Data Science Premier Project

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Import Dataset

# %%
night_df = pd.read_csv('Late_Night_Preferential_Runway_Use.csv')
complaint_df = pd.read_csv('aircraft-noise-complaint-data.csv')
airline_df = pd.read_csv('Noise_Exceedance_Rating.csv')
runway_df = pd.read_csv('air-carrier-runway-use.csv')

# %% [markdown]
# ### Preview dataset

# %%
night_df.head(10)
# Out:
#    Year  Month  01L/R  01L/R Percent of Departures  10L/R  \
# 0  2005      1     14                            6    164
# 1  2005      2     14                            7    158
# 2  2005      3     10                            4    165
# 3  2005      4     26                            9     99
# 4  2005      5     36                           10     90
# 5  2005      6     26                            6     96
# 6  2005      7     73                           18     63
# 7  2005      8    113                           28     85
# 8  2005      9     50                           13    140
# 9  2005     10     53                           15    131
#
#    10L/R Percent of Departures  19L/R  19L/R Percent of Departures  28L/R  \
# 0                           71      4                            2     49
# 1                           80      0                            0     25
# 2                           69      0                            0     65
# 3                           32      0                            0    180
# 4                           24      0                            0    242
# 5                           24      0                            0    285
# 6                           15      0                            0    275
# 7                           21      0                            0    211
# 8                           38      0                            0    181
# 9                           36      0                            0    181
#
#    28L/R Percent of Departures
# 0                           21
# 1                           13
# 2                           27
# 3                           59
# 4                           66
# 5                           70
# 6                           67
# 7                           52
# 8                           49
# 9                           50

# %%
complaint_df.head(10)
# Out:
#    Year  Month        Community  Total Complaints  Total Number of Callers
# 0  2018      2      San Leandro               1.0                      1.0
# 1  2018      4       San Carlos              64.0                      2.0
# 2  2018      6       El Granada             475.0                      1.0
# 3  2018      4      Santa Clara              15.0                      1.0
# 4  2018      8        Los Altos           25681.0                    163.0
# 5  2018      6        Palo Alto           48093.0                    239.0
# 6  2018      7            Aptos             812.0                     11.0
# 7  2018      3      Watsonville             175.0                      1.0
# 8  2018      7        Brookdale               4.0                      1.0
# 9  2018      3  Los Altos Hills            9153.0                     35.0

# %%
airline_df.head(10)
# Out:
#    Year    Month Airline Code            Airline  Total Noise Exceedances  \
# 0  2006  January          EJA   NETJETS AVIATION                        1
# 1  2006  January          SKW            SKYWEST                       15
# 2  2006  January          USA         US AIRWAYS                        2
# 3  2006  January          QXE        HORIZON AIR                        1
# 4  2006  January          DLH          LUFTHANSA                        1
# 5  2006  January          FFT  FRONTIER AIRLINES                        3
# 6  2006  January          AWE         US AIRWAYS                       10
# 7  2006  January          TRS    AIRTRAN AIRWAYS                        1
# 8  2006  January          AFR         AIR FRANCE                        1
# 9  2006  January          HAL  HAWAIIAN AIRLINES                        1
#
#    Total Operations per Month  Exceedances per 1000 Operations  \
# 0                         637                                2
# 1                        6752                                2
# 2                         388                                5
# 3                         168                                6
# 4                         108                                9
# 5                         289                               10
# 6                         731                               14
# 7                          67                               15
# 8                          62                               16
# 9                          62                               16
#
#    Noise Exceedance Quality Rating Score  Noise Exceedance Rating
# 0                                   9.99                     9.99
# 1                                   9.99                     9.99
# 2                                   9.97                     9.97
# 3                                   9.97                     9.97
# 4                                   9.95                     9.95
# 5                                   9.95                     9.95
# 6                                   9.93                     9.93
# 7                                   9.92                     9.92
# 8                                   9.92                     9.92
# 9                                   9.92                     9.92

# %%
runway_df.head(10)
# Out:
#    Year  Month  01L/R Departure 01L/R DeparturePercentage Utilization  \
# 0  2005      1           6977.0                                 59.7%
# 1  2005      2           6584.0                                 61.6%
# 2  2005      3           7165.0                                 59.3%
# 3  2005      4           7494.0                                   64%
# 4  2005      5           7767.0                                 63.1%
# 5  2005      6           5980.0                                 48.4%
# 6  2005      7           8380.0                                 68.5%
# 7  2005      8           9640.0                                 74.8%
# 8  2005      9           8999.0                                 75.1%
# 9  2005     10           9060.0                                 74.6%
#
#    10L/R Departure 10L/R DeparturePercentage Utilization  19L/R Departure  \
# 0           1554.0                                 13.3%            206.0
# 1           2348.0                                   22%             24.0
# 2           1232.0                                 10.2%             30.0
# 3            833.0                                  7.1%             69.0
# 4            792.0                                  6.4%              2.0
# 5            156.0                                  1.3%              0.0
# 6             69.0                                  0.6%              0.0
# 7             88.0                                  0.7%              0.0
# 8            153.0                                  1.3%              0.0
# 9            232.0                                  1.9%              0.0
#
#   19L/R DeparturePercentage Utilization  28L/R Departure  \
# 0                                  1.8%           2943.0
# 1                                  0.2%           1730.0
# 2                                  0.2%           3650.0
# 3                                  0.6%           3322.0
# 4                                    0%           3743.0
# 5                                    0%           6217.0
# 6                                    0%           3782.0
# 7                                    0%           3164.0
# 8                                    0%           2838.0
# 9                                    0%           2857.0
#
#   28L/R DeparturePercentage Utilization  01L/R Arrival  \
# 0                                 25.2%            0.0
# 1                                 16.2%            0.0
# 2                                 30.2%          118.0
# 3                                 28.3%            0.0
# 4                                 30.4%            0.0
# 5                                 50.3%            0.0
# 6                                 30.9%            3.0
# 7                                 24.5%            0.0
# 8                                 23.7%            0.0
# 9                                 23.5%            0.0
#
#   01L/R ArrivalPercentage Utilization  10L/R Arrival  \
# 0                                  0%            0.0
# 1                                  0%          125.0
# 2                                  1%            0.0
# 3                                  0%            2.0
# 4                                  0%            0.0
# 5                                  0%            0.0
# 6                                  0%            0.0
# 7                                  0%            0.0
# 8                                  0%            0.0
# 9                                  0%            0.0
#
#   10L/R ArrivalPercentage Utilization  19L/R Arrival  \
# 0                                  0%         1642.0
# 1                                1.2%         2125.0
# 2                                  0%         1144.0
# 3                                  0%          794.0
# 4                                  0%          677.0
# 5                                  0%           72.0
# 6                                  0%            0.0
# 7                                  0%            0.0
# 8                                  0%            0.0
# 9                                  0%           78.0
#
#   19L/R ArrivalPercentage Utilization  28L/R Arrival  \
# 0                               13.9%        10142.0
# 1                               19.7%         8533.0
# 2                                9.4%        10930.0
# 3                                6.7%        11077.0
# 4                                5.4%        11799.0
# 5                                0.6%        12463.0
# 6                                  0%        12648.0
# 7                                  0%        13104.0
# 8                                  0%        12355.0
# 9                                0.6%        12515.0
#
#   28L/R ArrivalPercentage Utilization
# 0                               86.1%
# 1                               79.1%
# 2                               89.6%
# 3                               93.3%
# 4                               94.6%
# 5                               99.4%
# 6                                100%
# 7                                100%
# 8                                100%
# 9                               99.4%

# %% [markdown]
# ## Assessing the datasets

# %%
## Naming the dataframes
night_df.name = 'Late_night_dataframe'
runway_df.name = 'Runway_dataframe'
airline_df.name = 'Arline_dataframe'
complaint_df.name = 'Complaint_dataframe'

# %%
# Creating a function to assess the dataframes 
def assess(df):
    print('Checking the shape of {}'.format(df.name))
    print('The dataset has {} rows and {} columns'.format(df.shape[0], df.shape[1]))
    print('+' * 50)
    print('+' * 50)
    print('Checking the number of duplicate values')
    print('{} has {} duplicates'.format(df.name, df.duplicated().sum()))
    print('+' * 50)
    print('+' * 50)
    print('Checking the number of null values')
    print(df.isna().sum())
    print('+' * 50)
    print('+' * 50)
    print('Checking the data types')
    print(df.info())
    print('+' * 50)
    print('+' * 50)

# %% [markdown]
# #### Asssessing complaint dataframe

# %%
assess(complaint_df)
# Out:
# Checking the shape of Complaint_dataframe
# The dataset has 4081 rows and 5 columns
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of duplicate values
# Complaint_dataframe has 0 duplicates
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of null values
# Year                       0
# Month                      0
# Community                  0
# Total Complaints           1
# Total Number of Callers    1
# dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the data types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4081 entries, 0 to 4080
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     4081 non-null   int64
#  1   Month                    4081 non-null   int64
#  2   Community                4081 non-null   object
#  3   Total Complaints         4080 non-null   float64
#  4   Total Number of Callers  4080 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 159.5+ KB
# None
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Assessing the late night preferential runway dataframe

# %%
assess(night_df)
# Out:
# Checking the shape of Late_night_dataframe
# The dataset has 175 rows and 10 columns
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of duplicate values
# Late_night_dataframe has 0 duplicates
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of null values
# Year                           0
# Month                          0
# 01L/R                          0
# 01L/R Percent of Departures    0
# 10L/R                          0
# 10L/R Percent of Departures    0
# 19L/R                          0
# 19L/R Percent of Departures    0
# 28L/R                          0
# 28L/R Percent of Departures    0
# dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the data types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         175 non-null    int64
#  1   Month                        175 non-null    int64
#  2   01L/R                        175 non-null    int64
#  3   01L/R Percent of Departures  175 non-null    int64
#  4   10L/R                        175 non-null    int64
#  5   10L/R Percent of Departures  175 non-null    int64
#  6   19L/R                        175 non-null    int64
#  7   19L/R Percent of Departures  175 non-null    int64
#  8   28L/R                        175 non-null    int64
#  9   28L/R Percent of Departures  175 non-null    int64
# dtypes: int64(10)
# memory usage: 13.8 KB
# None
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Assessing the noise exceedance rating for each airline

# %%
assess(airline_df)
# Out:
# Checking the shape of Arline_dataframe
# The dataset has 6280 rows and 9 columns
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of duplicate values
# Arline_dataframe has 0 duplicates
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of null values
# Year                                      0
# Month                                     0
# Airline Code                              0
# Airline                                  14
# Total Noise Exceedances                   0
# Total Operations per Month                0
# Exceedances per 1000 Operations           0
# Noise Exceedance Quality Rating Score     0
# Noise Exceedance Rating                   0
# dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the data types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6280 entries, 0 to 6279
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Year                                   6280 non-null   int64
#  1   Month                                  6280 non-null   object
#  2   Airline Code                           6280 non-null   object
#  3   Airline                                6266 non-null   object
#  4   Total Noise Exceedances                6280 non-null   int64
#  5   Total Operations per Month             6280 non-null   int64
#  6   Exceedances per 1000 Operations        6280 non-null   int64
#  7   Noise Exceedance Quality Rating Score  6280 non-null   float64
#  8   Noise Exceedance Rating                6280 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 441.7+ KB
# None
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Assessing the runway use dataframe

# %%
assess(runway_df)
# Out:
# Checking the shape of Runway_dataframe
# The dataset has 132 rows and 18 columns
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of duplicate values
# Runway_dataframe has 0 duplicates
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the number of null values
# Year                                     0
# Month                                    0
# 01L/R Departure                          1
# 01L/R DeparturePercentage Utilization    1
# 10L/R Departure                          1
# 10L/R DeparturePercentage Utilization    1
# 19L/R Departure                          1
# 19L/R DeparturePercentage Utilization    1
# 28L/R Departure                          1
# 28L/R DeparturePercentage Utilization    1
# 01L/R Arrival                            1
# 01L/R ArrivalPercentage Utilization      1
# 10L/R Arrival                            1
# 10L/R ArrivalPercentage Utilization      1
# 19L/R Arrival                            1
# 19L/R ArrivalPercentage Utilization      1
# 28L/R Arrival                            1
# 28L/R ArrivalPercentage Utilization      1
# dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking the data types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Year                                   132 non-null    int64
#  1   Month                                  132 non-null    int64
#  2   01L/R Departure                        131 non-null    float64
#  3   01L/R DeparturePercentage Utilization  131 non-null    object
#  4   10L/R Departure                        131 non-null    float64
#  5   10L/R DeparturePercentage Utilization  131 non-null    object
#  6   19L/R Departure                        131 non-null    float64
#  7   19L/R DeparturePercentage Utilization  131 non-null    object
#  8   28L/R Departure                        131 non-null    float64
#  9   28L/R DeparturePercentage Utilization  131 non-null    object
#  10  01L/R Arrival                          131 non-null    float64
#  11  01L/R ArrivalPercentage Utilization    131 non-null    object
#  12  10L/R Arrival                          131 non-null    float64
#  13  10L/R ArrivalPercentage Utilization    131 non-null    object
#  14  19L/R Arrival                          131 non-null    float64
#  15  19L/R ArrivalPercentage Utilization    131 non-null    object
#  16  28L/R Arrival                          131 non-null    float64
#  17  28L/R ArrivalPercentage Utilization    131 non-null    object
# dtypes: float64(8), int64(2), object(8)
# memory usage: 18.7+ KB
# None
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# From the assessment above. The following are deduced;
#
# * none of the dataset has  value
#
# * the complaint dataframe has 1 missing row values, the night_df has no missing value, the airline column of the airline_df has 14 missing values, and the runway_df has 1 missing row values
#
# * all the dataset has correct data types except the month column in the airline_df dataframe. The month is in text format - an object data type.
#
# Corrections:
#
# 1. The month column values will be replaced with corresponding numbers.
#
# 2. Remove unnecessary columns that are not needed for the analysis.
#
# 3. Afterwards, the night_df and runway_df datasets will be merged together based on the primary keys - the year and the month.

# %% [markdown]
# ### Correction 1 - replacing the month values in _airline_df_ with corresponding numbers

# %%
# preview the airline_df
airline_df.head()
# Out:
#    Year    Month Airline Code           Airline  Total Noise Exceedances  \
# 0  2006  January          EJA  NETJETS AVIATION                        1
# 1  2006  January          SKW           SKYWEST                       15
# 2  2006  January          USA        US AIRWAYS                        2
# 3  2006  January          QXE       HORIZON AIR                        1
# 4  2006  January          DLH         LUFTHANSA                        1
#
#    Total Operations per Month  Exceedances per 1000 Operations  \
# 0                         637                                2
# 1                        6752                                2
# 2                         388                                5
# 3                         168                                6
# 4                         108                                9
#
#    Noise Exceedance Quality Rating Score  Noise Exceedance Rating
# 0                                   9.99                     9.99
# 1                                   9.99                     9.99
# 2                                   9.97                     9.97
# 3                                   9.97                     9.97
# 4                                   9.95                     9.95

# %%
# check the unique values in the month column
airline_df.Month.unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'August',
#        'September', 'October', 'November', 'December', 'July', 'APRIL',
#        'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER',
#        'NOVEMBER', 'DECEMBER', 'JANUARY', 'FEBRUARY', 'MARCH'],
#       dtype=object)

# %% [markdown]
# #### Since the values are in both capital and upper form. We'll capitalize the values for uniformity

# %%
# capitalize the values
airline_df.Month = airline_df.Month.str.capitalize()

# replace the values with the corresponding numbers
airline_df.replace({'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, \
                    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12,\
                   }, inplace = True)

# %%
# check the unique values again for confirmation
airline_df.Month.unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  8,  9, 10, 11, 12,  7], dtype=int64)

# %%
night_df.head()
# Out:
#    Year  Month  01L/R  01L/R Percent of Departures  10L/R  \
# 0  2005      1     14                            6    164
# 1  2005      2     14                            7    158
# 2  2005      3     10                            4    165
# 3  2005      4     26                            9     99
# 4  2005      5     36                           10     90
#
#    10L/R Percent of Departures  19L/R  19L/R Percent of Departures  28L/R  \
# 0                           71      4                            2     49
# 1                           80      0                            0     25
# 2                           69      0                            0     65
# 3                           32      0                            0    180
# 4                           24      0                            0    242
#
#    28L/R Percent of Departures
# 0                           21
# 1                           13
# 2                           27
# 3                           59
# 4                           66

# %%
complaint_df.head()
# Out:
#    Year  Month    Community  Total Complaints  Total Number of Callers
# 0  2018      2  San Leandro               1.0                      1.0
# 1  2018      4   San Carlos              64.0                      2.0
# 2  2018      6   El Granada             475.0                      1.0
# 3  2018      4  Santa Clara              15.0                      1.0
# 4  2018      8    Los Altos           25681.0                    163.0

# %%
runway_df.head()
# Out:
#    Year  Month  01L/R Departure 01L/R DeparturePercentage Utilization  \
# 0  2005      1           6977.0                                 59.7%
# 1  2005      2           6584.0                                 61.6%
# 2  2005      3           7165.0                                 59.3%
# 3  2005      4           7494.0                                   64%
# 4  2005      5           7767.0                                 63.1%
#
#    10L/R Departure 10L/R DeparturePercentage Utilization  19L/R Departure  \
# 0           1554.0                                 13.3%            206.0
# 1           2348.0                                   22%             24.0
# 2           1232.0                                 10.2%             30.0
# 3            833.0                                  7.1%             69.0
# 4            792.0                                  6.4%              2.0
#
#   19L/R DeparturePercentage Utilization  28L/R Departure  \
# 0                                  1.8%           2943.0
# 1                                  0.2%           1730.0
# 2                                  0.2%           3650.0
# 3                                  0.6%           3322.0
# 4                                    0%           3743.0
#
#   28L/R DeparturePercentage Utilization  01L/R Arrival  \
# 0                                 25.2%            0.0
# 1                                 16.2%            0.0
# 2                                 30.2%          118.0
# 3                                 28.3%            0.0
# 4                                 30.4%            0.0
#
#   01L/R ArrivalPercentage Utilization  10L/R Arrival  \
# 0                                  0%            0.0
# 1                                  0%          125.0
# 2                                  1%            0.0
# 3                                  0%            2.0
# 4                                  0%            0.0
#
#   10L/R ArrivalPercentage Utilization  19L/R Arrival  \
# 0                                  0%         1642.0
# 1                                1.2%         2125.0
# 2                                  0%         1144.0
# 3                                  0%          794.0
# 4                                  0%          677.0
#
#   19L/R ArrivalPercentage Utilization  28L/R Arrival  \
# 0                               13.9%        10142.0
# 1                               19.7%         8533.0
# 2                                9.4%        10930.0
# 3                                6.7%        11077.0
# 4                                5.4%        11799.0
#
#   28L/R ArrivalPercentage Utilization
# 0                               86.1%
# 1                               79.1%
# 2                               89.6%
# 3                               93.3%
# 4                               94.6%

# %% [markdown]
# ### Correction 2 - remove unnecessary columns

# %% [markdown]
#  Since, we are focusing on the departure flights from SFO, we will be removing the arrival columns from runway_df

# %%
runway_df = runway_df[runway_df.columns.difference(['01L/R Arrival', '01L/R ArrivalPercentage Utilization', '10L/R Arrival',\
                                           '10L/R ArrivalPercentage Utilization', '19L/R Arrival', \
                                           '19L/R ArrivalPercentage Utilization', '28L/R Arrival', '28L/R ArrivalPercentage Utilization'])]

# %%
runway_df
# Out:
#      01L/R Departure 01L/R DeparturePercentage Utilization  10L/R Departure  \
# 0             6977.0                                 59.7%           1554.0
# 1             6584.0                                 61.6%           2348.0
# 2             7165.0                                 59.3%           1232.0
# 3             7494.0                                   64%            833.0
# 4             7767.0                                 63.1%            792.0
# ..               ...                                   ...              ...
# 127          14674.0                                 80.9%              2.0
# 128          12255.0                                 74.1%             10.0
# 129          14535.0                                 82.6%              5.0
# 130          13544.0                                 82.1%             20.0
# 131              NaN                                   NaN              NaN
#
#     10L/R DeparturePercentage Utilization  19L/R Departure  \
# 0                                   13.3%            206.0
# 1                                     22%             24.0
# 2                                   10.2%             30.0
# 3                                    7.1%             69.0
# 4                                    6.4%              2.0
# ..                                    ...              ...
# 127                                    0%              0.0
# 128                                  0.1%              0.0
# 129                                    0%              0.0
# 130                                  0.1%              0.0
# 131                                   NaN              NaN
#
#     19L/R DeparturePercentage Utilization  28L/R Departure  \
# 0                                    1.8%           2943.0
# 1                                    0.2%           1730.0
# 2                                    0.2%           3650.0
# 3                                    0.6%           3322.0
# 4                                      0%           3743.0
# ..                                    ...              ...
# 127                                    0%           3464.0
# 128                                    0%           4266.0
# 129                                    0%           3052.0
# 130                                    0%           2930.0
# 131                                   NaN              NaN
#
#     28L/R DeparturePercentage Utilization  Month  Year
# 0                                   25.2%      1  2005
# 1                                   16.2%      2  2005
# 2                                   30.2%      3  2005
# 3                                   28.3%      4  2005
# 4                                   30.4%      5  2005
# ..                                    ...    ...   ...
# 127                                 19.1%      8  2015
# 128                                 25.8%      9  2015
# 129                                 17.3%     10  2015
# 130                                 17.8%     11  2015
# 131                                   NaN     12  2015
#
# [132 rows x 10 columns]

# %% [markdown]
# Remove "Noise Exceedance Quality Rating Score". It is same as 'Noise Exceeding Rating'.

# %%
airline_df.drop('Noise Exceedance Quality Rating Score', axis = 1, inplace = True)

# %%
airline_df.head()
# Out:
#    Year  Month Airline Code           Airline  Total Noise Exceedances  \
# 0  2006      1          EJA  NETJETS AVIATION                        1
# 1  2006      1          SKW           SKYWEST                       15
# 2  2006      1          USA        US AIRWAYS                        2
# 3  2006      1          QXE       HORIZON AIR                        1
# 4  2006      1          DLH         LUFTHANSA                        1
#
#    Total Operations per Month  Exceedances per 1000 Operations  \
# 0                         637                                2
# 1                        6752                                2
# 2                         388                                5
# 3                         168                                6
# 4                         108                                9
#
#    Noise Exceedance Rating
# 0                     9.99
# 1                     9.99
# 2                     9.97
# 3                     9.97
# 4                     9.95

# %% [markdown]
# ### Correction 3 - Merge the night_df and runway_df datasets together based on the year and month

# %%
# merge the datasets
merged_df = pd.merge(night_df, runway_df, on=['Year', 'Month'])
merged_df.head()
# Out:
#    Year  Month  01L/R  01L/R Percent of Departures  10L/R  \
# 0  2005      1     14                            6    164
# 1  2005      2     14                            7    158
# 2  2005      3     10                            4    165
# 3  2005      4     26                            9     99
# 4  2005      5     36                           10     90
#
#    10L/R Percent of Departures  19L/R  19L/R Percent of Departures  28L/R  \
# 0                           71      4                            2     49
# 1                           80      0                            0     25
# 2                           69      0                            0     65
# 3                           32      0                            0    180
# 4                           24      0                            0    242
#
#    28L/R Percent of Departures  01L/R Departure  \
# 0                           21           6977.0
# 1                           13           6584.0
# 2                           27           7165.0
# 3                           59           7494.0
# 4                           66           7767.0
#
#   01L/R DeparturePercentage Utilization  10L/R Departure  \
# 0                                 59.7%           1554.0
# 1                                 61.6%           2348.0
# 2                                 59.3%           1232.0
# 3                                   64%            833.0
# 4                                 63.1%            792.0
#
#   10L/R DeparturePercentage Utilization  19L/R Departure  \
# 0                                 13.3%            206.0
# 1                                   22%             24.0
# 2                                 10.2%             30.0
# 3                                  7.1%             69.0
# 4                                  6.4%              2.0
#
#   19L/R DeparturePercentage Utilization  28L/R Departure  \
# 0                                  1.8%           2943.0
# 1                                  0.2%           1730.0
# 2                                  0.2%           3650.0
# 3                                  0.6%           3322.0
# 4                                    0%           3743.0
#
#   28L/R DeparturePercentage Utilization
# 0                                 25.2%
# 1                                 16.2%
# 2                                 30.2%
# 3                                 28.3%
# 4                                 30.4%

# %% [markdown]
# #### Rename the columns

# %%
# rename the column names to a more conscise and understandable one
merged_df = merged_df.rename(columns = {'01L/R': 'night_01L/R', '01L/R Percent of Departures': 'night_01L/R_percent', '10L/R': 'night_10L/R',\
                  '10L/R Percent of Departures': 'night_10L/R_percent', '19L/R': 'night_19L/R', '19L/R Percent of Departures': 'night_19L/R_percent',\
                  '28L/R': 'night_28L/R', '28L/R Percent of Departures': 'night_28L/R_percent', '01L/R Departure': 'total_01L/R',\
                  '01L/R DeparturePercentage Utilization': 'total_01L/R_percent', '10L/R Departure' : 'total_10L/R',\
                  '10L/R DeparturePercentage Utilization' : 'total_10L/R_percent', '19L/R Departure': 'total_19L/R',\
                  '19L/R DeparturePercentage Utilization': 'total_19L/R_percent', '28L/R Departure': 'total_28L/R',\
                  '28L/R DeparturePercentage Utilization': 'total_28L/R_percent'})

# %%
merged_df.columns = merged_df.columns.str.lower()

# %%
merged_df.head()
# Out:
#    year  month  night_01l/r  night_01l/r_percent  night_10l/r  \
# 0  2005      1           14                    6          164
# 1  2005      2           14                    7          158
# 2  2005      3           10                    4          165
# 3  2005      4           26                    9           99
# 4  2005      5           36                   10           90
#
#    night_10l/r_percent  night_19l/r  night_19l/r_percent  night_28l/r  \
# 0                   71            4                    2           49
# 1                   80            0                    0           25
# 2                   69            0                    0           65
# 3                   32            0                    0          180
# 4                   24            0                    0          242
#
#    night_28l/r_percent  total_01l/r total_01l/r_percent  total_10l/r  \
# 0                   21       6977.0               59.7%       1554.0
# 1                   13       6584.0               61.6%       2348.0
# 2                   27       7165.0               59.3%       1232.0
# 3                   59       7494.0                 64%        833.0
# 4                   66       7767.0               63.1%        792.0
#
#   total_10l/r_percent  total_19l/r total_19l/r_percent  total_28l/r  \
# 0               13.3%        206.0                1.8%       2943.0
# 1                 22%         24.0                0.2%       1730.0
# 2               10.2%         30.0                0.2%       3650.0
# 3                7.1%         69.0                0.6%       3322.0
# 4                6.4%          2.0                  0%       3743.0
#
#   total_28l/r_percent
# 0               25.2%
# 1               16.2%
# 2               30.2%
# 3               28.3%
# 4               30.4%

# %% [markdown]
# #### We now have 3 main datasets - merged_df (consist of night_df and runway_df merged together), airline_df and complaint_df
# Lets preview the dataset below:

# %%
merged_df.head()
# Out:
#    year  month  night_01l/r  night_01l/r_percent  night_10l/r  \
# 0  2005      1           14                    6          164
# 1  2005      2           14                    7          158
# 2  2005      3           10                    4          165
# 3  2005      4           26                    9           99
# 4  2005      5           36                   10           90
#
#    night_10l/r_percent  night_19l/r  night_19l/r_percent  night_28l/r  \
# 0                   71            4                    2           49
# 1                   80            0                    0           25
# 2                   69            0                    0           65
# 3                   32            0                    0          180
# 4                   24            0                    0          242
#
#    night_28l/r_percent  total_01l/r total_01l/r_percent  total_10l/r  \
# 0                   21       6977.0               59.7%       1554.0
# 1                   13       6584.0               61.6%       2348.0
# 2                   27       7165.0               59.3%       1232.0
# 3                   59       7494.0                 64%        833.0
# 4                   66       7767.0               63.1%        792.0
#
#   total_10l/r_percent  total_19l/r total_19l/r_percent  total_28l/r  \
# 0               13.3%        206.0                1.8%       2943.0
# 1                 22%         24.0                0.2%       1730.0
# 2               10.2%         30.0                0.2%       3650.0
# 3                7.1%         69.0                0.6%       3322.0
# 4                6.4%          2.0                  0%       3743.0
#
#   total_28l/r_percent
# 0               25.2%
# 1               16.2%
# 2               30.2%
# 3               28.3%
# 4               30.4%

# %%
airline_df.head()
# Out:
#    Year  Month Airline Code           Airline  Total Noise Exceedances  \
# 0  2006      1          EJA  NETJETS AVIATION                        1
# 1  2006      1          SKW           SKYWEST                       15
# 2  2006      1          USA        US AIRWAYS                        2
# 3  2006      1          QXE       HORIZON AIR                        1
# 4  2006      1          DLH         LUFTHANSA                        1
#
#    Total Operations per Month  Exceedances per 1000 Operations  \
# 0                         637                                2
# 1                        6752                                2
# 2                         388                                5
# 3                         168                                6
# 4                         108                                9
#
#    Noise Exceedance Rating
# 0                     9.99
# 1                     9.99
# 2                     9.97
# 3                     9.97
# 4                     9.95

# %%
complaint_df.head()
# Out:
#    Year  Month    Community  Total Complaints  Total Number of Callers
# 0  2018      2  San Leandro               1.0                      1.0
# 1  2018      4   San Carlos              64.0                      2.0
# 2  2018      6   El Granada             475.0                      1.0
# 3  2018      4  Santa Clara              15.0                      1.0
# 4  2018      8    Los Altos           25681.0                    163.0

# %% [markdown]
# ## Analysis

# %%
merged_df.head()
# Out:
#    year  month  night_01l/r  night_01l/r_percent  night_10l/r  \
# 0  2005      1           14                    6          164
# 1  2005      2           14                    7          158
# 2  2005      3           10                    4          165
# 3  2005      4           26                    9           99
# 4  2005      5           36                   10           90
#
#    night_10l/r_percent  night_19l/r  night_19l/r_percent  night_28l/r  \
# 0                   71            4                    2           49
# 1                   80            0                    0           25
# 2                   69            0                    0           65
# 3                   32            0                    0          180
# 4                   24            0                    0          242
#
#    night_28l/r_percent  total_01l/r total_01l/r_percent  total_10l/r  \
# 0                   21       6977.0               59.7%       1554.0
# 1                   13       6584.0               61.6%       2348.0
# 2                   27       7165.0               59.3%       1232.0
# 3                   59       7494.0                 64%        833.0
# 4                   66       7767.0               63.1%        792.0
#
#   total_10l/r_percent  total_19l/r total_19l/r_percent  total_28l/r  \
# 0               13.3%        206.0                1.8%       2943.0
# 1                 22%         24.0                0.2%       1730.0
# 2               10.2%         30.0                0.2%       3650.0
# 3                7.1%         69.0                0.6%       3322.0
# 4                6.4%          2.0                  0%       3743.0
#
#   total_28l/r_percent
# 0               25.2%
# 1               16.2%
# 2               30.2%
# 3               28.3%
# 4               30.4%

# %%
runway_night = ['night_01l/r', 'night_10l/r', 'night_19l/r', 'night_28l/r']
runway_total = ['total_01l/r', 'total_10l/r', 'total_19l/r', 'total_28l/r']

# %% [markdown]
# ## Total number of night flights per year in SFO from 2005 - 2019

# %%
# Group the data by year and sum the values of runway_night columns for each year
night_flights_by_year = merged_df[runway_night + ['year']].groupby('year').sum()

# Set the size of the plot
plt.figure(figsize=(12, 8))

# Set the line color and style
plt.plot(night_flights_by_year.index, night_flights_by_year.values, linewidth=2, label = ['01L/R', '10L/R', '19L/R', '28L/R'])

# Add a title and axis labels
plt.title('Night Flights per Year', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Night Flights', fontsize=14)

# Customize the tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Set the background color
plt.gca().set_facecolor('white')

# set legend
plt.legend(loc='upper left', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ## Total number of flights per year in SFO from 2005 - 2019

# %%
# Group the data by year and sum the values of runway_ column for each year
total_flights_by_year = merged_df[runway_total + ['year']].groupby('year').sum()

# Set the size of the plot
plt.figure(figsize=(12, 8))

# Set the line color and style
plt.plot(total_flights_by_year.index, total_flights_by_year.values, linewidth=2, label = ['01L/R', '10L/R', '19L/R', '28L/R'])

# Add a title and axis labels
plt.title('Total Flights per Year', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Number of Flights', fontsize=14)

# Customize the tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Set the background color
plt.gca().set_facecolor('white')

# set legend
plt.legend(loc='upper left', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ## Total number of night flights per month in SFO from 2005 - 2019

# %%
# Group the data by month and sum the values of runway_night columns for each month
night_flights_by_month = merged_df[runway_night + ['month']].groupby('month').sum()

# Set the size of the plot
plt.figure(figsize=(12, 8))

# Set the line color and style
plt.plot(night_flights_by_month.index, night_flights_by_month.values, linewidth=2, label = ['01L/R', '10L/R', '19L/R', '28L/R'])

# Add a title and axis labels
plt.title('Night Flights per Month', fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Night Flights', fontsize=14)

# Customize the tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Set the background color
plt.gca().set_facecolor('white')

# set legend
plt.legend(loc='upper left', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ## Total number of flights per month in SFO from 2005 - 2019

# %%
# Group the data by month and sum the values of runway_ column for each month
total_flights_by_month = merged_df[runway_total + ['month']].groupby('month').sum()

# Set the size of the plot
plt.figure(figsize=(12, 8))

# Set the line color and style
plt.plot(total_flights_by_month.index, total_flights_by_month.values, linewidth=2, label = ['01L/R', '10L/R', '19L/R', '28L/R'])

# Add a title and axis labels
plt.title('Total Flights per month', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Number of Flights', fontsize=14)

# Customize the tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Set the background color
plt.gca().set_facecolor('white')

# set legend
plt.legend(loc='upper left', fontsize=12)

# Display the plot
plt.show()

# %%
merged_df.head()
# Out:
#    year  month  night_01l/r  night_01l/r_percent  night_10l/r  \
# 0  2005      1           14                    6          164
# 1  2005      2           14                    7          158
# 2  2005      3           10                    4          165
# 3  2005      4           26                    9           99
# 4  2005      5           36                   10           90
#
#    night_10l/r_percent  night_19l/r  night_19l/r_percent  night_28l/r  \
# 0                   71            4                    2           49
# 1                   80            0                    0           25
# 2                   69            0                    0           65
# 3                   32            0                    0          180
# 4                   24            0                    0          242
#
#    night_28l/r_percent  total_01l/r total_01l/r_percent  total_10l/r  \
# 0                   21       6977.0               59.7%       1554.0
# 1                   13       6584.0               61.6%       2348.0
# 2                   27       7165.0               59.3%       1232.0
# 3                   59       7494.0                 64%        833.0
# 4                   66       7767.0               63.1%        792.0
#
#   total_10l/r_percent  total_19l/r total_19l/r_percent  total_28l/r  \
# 0               13.3%        206.0                1.8%       2943.0
# 1                 22%         24.0                0.2%       1730.0
# 2               10.2%         30.0                0.2%       3650.0
# 3                7.1%         69.0                0.6%       3322.0
# 4                6.4%          2.0                  0%       3743.0
#
#   total_28l/r_percent
# 0               25.2%
# 1               16.2%
# 2               30.2%
# 3               28.3%
# 4               30.4%

# %%
airline_df.head()
# Out:
#    Year  Month Airline Code           Airline  Total Noise Exceedances  \
# 0  2006      1          EJA  NETJETS AVIATION                        1
# 1  2006      1          SKW           SKYWEST                       15
# 2  2006      1          USA        US AIRWAYS                        2
# 3  2006      1          QXE       HORIZON AIR                        1
# 4  2006      1          DLH         LUFTHANSA                        1
#
#    Total Operations per Month  Exceedances per 1000 Operations  \
# 0                         637                                2
# 1                        6752                                2
# 2                         388                                5
# 3                         168                                6
# 4                         108                                9
#
#    Noise Exceedance Rating
# 0                     9.99
# 1                     9.99
# 2                     9.97
# 3                     9.97
# 4                     9.95

# %%
airline_df.Airline =airline_df.Airline.str.capitalize()

# %% [markdown]
# ## Top 10 airlines with the highest average "Noise Exceedance Rating"
# These airlines produce lesser noise pollution.

# %% [markdown]
# NOte: There are inconsistency with the dataset. Some airlines are represented by more than one name e.g. NETJETS is represented by both NETJETS and NETJETS AVIATION. Hence, the airline code will be use instead for the analysis.

# %%
top_airlines = airline_df[['Noise Exceedance Rating', 'Airline Code']].groupby('Airline Code').mean().sort_values(by='Noise Exceedance Rating', ascending=False)[:10]
top_airlines.plot(kind='bar', figsize=(10, 8))
plt.ylim(9.8, 10) # Set the y-axis limits to 9.8 and 10
plt.title('Top 10 Airlines that produces least noise pollution')
plt.xticks(rotation = 0)
plt.xlabel('Airline')
plt.ylabel('Mean Noise Exceedance Rating')
plt.show()

# %% [markdown]
# The above 10 airlines are recommended for a more effective noise pollution management.

# %% [markdown]
# ## Airlines having their average "Noise Exceedance Rating" less than 5.0
# These airlines produce greatest noise pollution.

# %%
top_airlines = airline_df[['Noise Exceedance Rating', 'Airline Code']].groupby('Airline Code').mean().sort_values(by='Noise Exceedance Rating', ascending=True)
top_airlines = top_airlines[top_airlines['Noise Exceedance Rating'] < 5]
top_airlines.plot(kind='bar', figsize=(12, 8))
# plt.ylim(8, 10) # Set the y-axis limits to 8 and 10
plt.title('Top 10 Airlines that produces greatest noise pollution')
plt.xticks(rotation = 0)
plt.xlabel('Airline')
plt.ylabel('Mean Noise Exceedance Rating')
plt.show()

# %% [markdown]
# > The above airlines produce the greatest noise pollution. Bans could probably be placed on the airlines until they are able to provide better aircrafts with noise-reduction control system.

# %% [markdown]
# ## Complaints Analysis

# %%
complaint_df.head()
# Out:
#    Year  Month    Community  Total Complaints  Total Number of Callers
# 0  2018      2  San Leandro               1.0                      1.0
# 1  2018      4   San Carlos              64.0                      2.0
# 2  2018      6   El Granada             475.0                      1.0
# 3  2018      4  Santa Clara              15.0                      1.0
# 4  2018      8    Los Altos           25681.0                    163.0

# %%
grouped_complaints = complaint_df[['Community', 'Total Complaints']].groupby('Community').sum().sort_values(by = 'Total Complaints', ascending = False)[:10]

grouped_complaints.plot(kind='bar', figsize=(12, 8))
plt.title('Total Complaints by community')
plt.xticks(rotation = 0)
plt.xlabel('Community')
plt.ylabel('Total complaints')
plt.show()

# %% [markdown]
# Palo Alto is affected more by the noise pollution

# %% [markdown]
# ## Correlation Metrics

# %%
merged_df.head()
# Out:
#    year  month  night_01l/r  night_01l/r_percent  night_10l/r  \
# 0  2005      1           14                    6          164
# 1  2005      2           14                    7          158
# 2  2005      3           10                    4          165
# 3  2005      4           26                    9           99
# 4  2005      5           36                   10           90
#
#    night_10l/r_percent  night_19l/r  night_19l/r_percent  night_28l/r  \
# 0                   71            4                    2           49
# 1                   80            0                    0           25
# 2                   69            0                    0           65
# 3                   32            0                    0          180
# 4                   24            0                    0          242
#
#    night_28l/r_percent  total_01l/r total_01l/r_percent  total_10l/r  \
# 0                   21       6977.0               59.7%       1554.0
# 1                   13       6584.0               61.6%       2348.0
# 2                   27       7165.0               59.3%       1232.0
# 3                   59       7494.0                 64%        833.0
# 4                   66       7767.0               63.1%        792.0
#
#   total_10l/r_percent  total_19l/r total_19l/r_percent  total_28l/r  \
# 0               13.3%        206.0                1.8%       2943.0
# 1                 22%         24.0                0.2%       1730.0
# 2               10.2%         30.0                0.2%       3650.0
# 3                7.1%         69.0                0.6%       3322.0
# 4                6.4%          2.0                  0%       3743.0
#
#   total_28l/r_percent
# 0               25.2%
# 1               16.2%
# 2               30.2%
# 3               28.3%
# 4               30.4%

# %%
# Create a df by subsetting runway usage data and the month and year
df_corr = merged_df[['year', 'month', 'night_01l/r', 'night_10l/r', 'night_19l/r',
                     'night_28l/r', 'total_01l/r', 'total_10l/r','total_19l/r',
                     'total_28l/r',]].corr()
df_corr.head()
# Out:
#                      year         month  night_01l/r  night_10l/r  \
# year         1.000000e+00  1.242623e-14     0.589112    -0.702349
# month        1.242623e-14  1.000000e+00     0.195687    -0.066543
# night_01l/r  5.891125e-01  1.956871e-01     1.000000    -0.598523
# night_10l/r -7.023494e-01 -6.654287e-02    -0.598523     1.000000
# night_19l/r  7.184898e-02 -3.258625e-02    -0.084067     0.211839
#
#              night_19l/r  night_28l/r  total_01l/r  total_10l/r  total_19l/r  \
# year            0.071849     0.145957     0.489820    -0.223953    -0.056031
# month          -0.032586     0.081872     0.282422    -0.176519    -0.136970
# night_01l/r    -0.084067     0.370173     0.665644    -0.389924    -0.218022
# night_10l/r     0.211839    -0.574304    -0.513320     0.703340     0.416928
# night_19l/r     1.000000    -0.293616    -0.117239     0.402664     0.528428
#
#              total_28l/r
# year            0.129048
# month          -0.104079
# night_01l/r    -0.107152
# night_10l/r    -0.275290
# night_19l/r    -0.122063

# %%
# Heatmap to show correlation coefficients and inspect contribution of each variables
ax = sns.heatmap(df_corr,annot=True, linewidths= 2)
plt.title('Heatmap Showing Correlation Among All Parameters')
plt.show(ax)

# %%
merged_df.to_csv('Merged_df.csv', index = False)
complaint_df.to_csv('Copl')
